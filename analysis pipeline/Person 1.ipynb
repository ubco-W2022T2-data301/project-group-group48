# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pylab as plt
import seaborn as sns

# %%
music = pd.read_csv("../data/raw/song_data.csv.zip")

# %%
music
# Out:
#                         song_name  song_popularity  song_duration_ms  \
# 0      Boulevard of Broken Dreams               73            262333
# 1                      In The End               66            216933
# 2               Seven Nation Army               76            231733
# 3                      By The Way               74            216933
# 4               How You Remind Me               56            223826
# ...                           ...              ...               ...
# 18830              Let It Breathe               60            159645
# 18831                     Answers               60            205666
# 18832      Sudden Love (Acoustic)               23            182211
# 18833           Gentle on My Mind               55            352280
# 18834                    Up to Me               60            193533
#
#        acousticness  danceability  energy  instrumentalness  key  liveness  \
# ...

# %% [markdown]
# # Cleaning Data

# %%
singsong = music.loc[0:499]
singsong
# Out:
#                       song_name  song_popularity  song_duration_ms  \
# 0    Boulevard of Broken Dreams               73            262333
# 1                    In The End               66            216933
# 2             Seven Nation Army               76            231733
# 3                    By The Way               74            216933
# 4             How You Remind Me               56            223826
# ..                          ...              ...               ...
# 495                 China Grove               67            195306
# 496        Foreplay / Long Time               64            467640
# 497              Come Sail Away               59            365000
# 498           Give A Little Bit               72            248173
# 499              Doctor My Eyes               64            199906
#
#      acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0        0.005520         0.496   0.682          0.000029    8    0.0589
# ...

# %%
singsong_cleaned = singsong.drop(['audio_mode','liveness', 'time_signature', 'instrumentalness'], axis=1)
singsong_cleaned
#Cleaning data. I'm cleaning by removing these 3 rows that either had 
#no significant variation or were repetetive to other rows
# Out:
#                       song_name  song_popularity  song_duration_ms  \
# 0    Boulevard of Broken Dreams               73            262333
# 1                    In The End               66            216933
# 2             Seven Nation Army               76            231733
# 3                    By The Way               74            216933
# 4             How You Remind Me               56            223826
# ..                          ...              ...               ...
# 495                 China Grove               67            195306
# 496        Foreplay / Long Time               64            467640
# 497              Come Sail Away               59            365000
# 498           Give A Little Bit               72            248173
# 499              Doctor My Eyes               64            199906
#
#      acousticness  danceability  energy  key  loudness  speechiness    tempo  \
# 0        0.005520         0.496   0.682    8    -4.095       0.0294  167.060
# ...

# %%
singsong_cleaned_1 = singsong_cleaned.dropna(axis=0)
singsong_cleaned_1.shape
# Out:
# (500, 11)

# %% [markdown]
# # Processing Data

# %%
singsong_cleaned['loudness_energy'] = singsong_cleaned['loudness'] + singsong_cleaned['energy']

# %%
singsong_cleaned['energy_duration'] = singsong_cleaned['song_duration_ms'] + singsong_cleaned['energy']

# %%
singsong_cleaned # this version of my repository has an additional column combining loudness and energy, the two most correlated elements.
# Out:
#                       song_name  song_popularity  song_duration_ms  \
# 0    Boulevard of Broken Dreams               73            262333
# 1                    In The End               66            216933
# 2             Seven Nation Army               76            231733
# 3                    By The Way               74            216933
# 4             How You Remind Me               56            223826
# ..                          ...              ...               ...
# 495                 China Grove               67            195306
# 496        Foreplay / Long Time               64            467640
# 497              Come Sail Away               59            365000
# 498           Give A Little Bit               72            248173
# 499              Doctor My Eyes               64            199906
#
#      acousticness  danceability  energy  key  loudness  speechiness    tempo  \
# 0        0.005520         0.496   0.682    8    -4.095       0.0294  167.060
# ...

# %% [markdown]
# # Wrangling Data

# %%
least_popular = singsong_cleaned.sort_values("song_popularity", ascending=True).head(20)
least_popular #these are the bottom 20 songs according to popularity
# Out:
#                                             song_name  song_popularity  \
# 225                                           Querida                4
# 229                   I Know You Want Me (Calle Ocho)                7
# 234                                      Besame Mucho                7
# 237                                         Chan Chan                7
# 338             Psychotic Reaction - Rarities Version                8
# 121                                   Beautiful Girls               10
# 36                                      The Pretender               11
# 30                                        All My Life               11
# 210                                        El Matador               11
# 282                                 Hit the Road Jack               13
# 22                                       No One Knows               13
# 363                          Wildflowers - Remastered               13
# ...

# %%
most_popular = singsong_cleaned.sort_values("song_popularity", ascending=False).head(20)
most_popular #these are the top twenty songs according to popularity
# Out:
#                                           song_name  song_popularity  \
# 61   Taki Taki (with Selena Gomez, Ozuna & Cardi B)               98
# 86                                        I Like It               95
# 85                                             BEBE               95
# 64                 Beautiful (feat. Camila Cabello)               94
# 60                                MIA (feat. Drake)               94
# 70                               Wake Up in the Sky               92
# 101     1, 2, 3 (feat. Jason Derulo & De La Ghetto)               88
# 65                                           Celoso               87
# 67                                     Real Friends               85
# 131                                       All of Me               85
# 212                                  Hips Don't Lie               84
# 114                 Finesse (Remix) [feat. Cardi B]               84
# 126                                  Hips Don't Lie               84
# ...

# %%
sorted_df = singsong_cleaned.sort_values('song_popularity')

midpoint = len(sorted_df) // 2

semi_popular = sorted_df.iloc[midpoint-5:midpoint+5]

semi_popular
# this code sorts the dataframe by song popularity in ascending order,
# calculates the midpoint index
# locates the 10 middle songs
# print the semi-popular songs
# Out:
#                                              song_name  song_popularity  \
# 309                            Revolution - Remastered               67
# 262                   Born To Be Wild - Single Version               67
# 325  With A Little Help From My Friends - Remastere...               67
# 465             We Are The Champions - Remastered 2011               67
# 450                      Iron Man - Remastered Version               67
# 297                             Paint It, Black - Mono               67
# 151                                          Sk8er Boi               67
# 399                                          Our House               67
# 171                                   It's Gonna Be Me               67
# 495                                        China Grove               67
#
#      song_duration_ms  acousticness  danceability  energy  key  loudness  \
# 309            205293      0.073400         0.407   0.834    6    -9.224
# ...

# %%
combo = pd.concat([most_popular, least_popular, semi_popular], axis=0).sort_values('song_popularity')
combo
# Out:
#                                              song_name  song_popularity  \
# 225                                            Querida                4
# 237                                          Chan Chan                7
# 234                                       Besame Mucho                7
# 229                    I Know You Want Me (Calle Ocho)                7
# 338              Psychotic Reaction - Rarities Version                8
# 121                                    Beautiful Girls               10
# 210                                         El Matador               11
# 36                                       The Pretender               11
# 30                                         All My Life               11
# 22                                        No One Knows               13
# 282                                  Hit the Road Jack               13
# 363                           Wildflowers - Remastered               13
# ...

# %%
combo.drop_duplicates(inplace=True) #Needed because there were duplicate rows in the first combo

# %%
combo
# Out:
#                                              song_name  song_popularity  \
# 225                                            Querida                4
# 237                                          Chan Chan                7
# 234                                       Besame Mucho                7
# 229                    I Know You Want Me (Calle Ocho)                7
# 338              Psychotic Reaction - Rarities Version                8
# 121                                    Beautiful Girls               10
# 210                                         El Matador               11
# 36                                       The Pretender               11
# 30                                         All My Life               11
# 22                                        No One Knows               13
# 282                                  Hit the Road Jack               13
# 363                           Wildflowers - Remastered               13
# ...

# %%
combo['genre'] = ['Latin Pop', 'Son cubano', 'Bolero', 'Hip Hop', 'Rock', 'R&B', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Salsa', 'Rock', 'Pop', 'R&B', 'Rock', 'Rock', 'Indie', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Pop', 'Rock', 'Rock', 'Rock', 'Rock', 'Pop', 'Pop', 'Pop', 'Pop', 'R&B', 'Pop', 'Reggae', 'Reggae', 'Hip Hop', 'Hip Hop', 'Pop', 'Pop', 'Hip Hop', 'Reggae']
combo
# Out:
#                                              song_name  song_popularity  \
# 225                                            Querida                4
# 237                                          Chan Chan                7
# 234                                       Besame Mucho                7
# 229                    I Know You Want Me (Calle Ocho)                7
# 338              Psychotic Reaction - Rarities Version                8
# 121                                    Beautiful Girls               10
# 210                                         El Matador               11
# 36                                       The Pretender               11
# 30                                         All My Life               11
# 22                                        No One Knows               13
# 282                                  Hit the Road Jack               13
# 363                           Wildflowers - Remastered               13
# ...

# %%
combo_2 = combo.reindex(columns=['song_name', 'genre', 'song_popularity', 'song_duration_ms', 'acousticness','danceability', 'energy', 'key', 'loudness', 'speechiness', 'tempo', 'audio_valence', 'loudness_energy', 'energy_duration'])
combo_2
# Out:
#                                              song_name       genre  \
# 234                                       Besame Mucho      Bolero
# 86                                           I Like It     Hip Hop
# 229                    I Know You Want Me (Calle Ocho)     Hip Hop
# 70                                  Wake Up in the Sky     Hip Hop
# 60                                   MIA (feat. Drake)     Hip Hop
# 325  With A Little Help From My Friends - Remastere...       Indie
# 225                                            Querida   Latin Pop
# 202                                    La Camisa Negra         Pop
# 85                                                BEBE         Pop
# 171                                   It's Gonna Be Me         Pop
# 71                                           Está Rico         Pop
# 114                    Finesse (Remix) [feat. Cardi B]         Pop
# 126                                     Hips Don't Lie         Pop
# ...

# %% [markdown]
# # Method Chaining

# %% [markdown]
# ### The following code finds the top 20, bottom 20 and middle 10 songs (popularity-wise) and puts them into a combo df. The df is sorted according to popularity. These are the same steps done before but lumped in a method chain

# %%
combo = (
    singsong_cleaned
    .sort_values('song_popularity')
    .pipe(lambda df: pd.concat([
        df.head(20),  # Top 20 most popular songs
        df.tail(20),  # Bottom 20 least popular songs
        df.iloc[len(df) // 2 - 5:len(df) // 2 + 5]  # Middle 10 songs
    ]))
    .sort_values('song_popularity')
)

# %%
combo
# Out:
#                                              song_name  song_popularity  \
# 225                                            Querida                4
# 229                    I Know You Want Me (Calle Ocho)                7
# 234                                       Besame Mucho                7
# 237                                          Chan Chan                7
# 338              Psychotic Reaction - Rarities Version                8
# 121                                    Beautiful Girls               10
# 36                                       The Pretender               11
# 30                                         All My Life               11
# 210                                         El Matador               11
# 282                                  Hit the Road Jack               13
# 22                                        No One Knows               13
# 363                           Wildflowers - Remastered               13
# ...

# %% [markdown]
# ### The following method chain drops duplicates, assigns genres to each song and reorders the columns so that genre is the second one.

# %%
combo_2 = (combo.drop_duplicates()
           .assign(genre=['Latin Pop', 'Son cubano', 'Bolero', 'Hip Hop', 'Rock', 'R&B', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Salsa', 'Rock', 'Pop', 'R&B', 'Rock', 'Rock', 'Indie', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Pop', 'Rock', 'Rock', 'Rock', 'Rock', 'Pop', 'Pop', 'Pop', 'Pop', 'R&B', 'Pop', 'Reggae', 'Reggae', 'Hip Hop', 'Hip Hop', 'Pop', 'Pop', 'Hip Hop', 'Reggae'])
           .reindex(columns=['song_name', 'genre', 'song_popularity', 'song_duration_ms', 'acousticness', 'danceability', 'energy', 'key', 'loudness', 'speechiness', 'tempo', 'audio_valence', 'loudness_energy', 'energy_duration']))
combo_2
# Out:
#                                              song_name       genre  \
# 225                                            Querida   Latin Pop
# 229                    I Know You Want Me (Calle Ocho)  Son cubano
# 234                                       Besame Mucho      Bolero
# 237                                          Chan Chan     Hip Hop
# 338              Psychotic Reaction - Rarities Version        Rock
# 121                                    Beautiful Girls         R&B
# 36                                       The Pretender        Rock
# 30                                         All My Life        Rock
# 210                                         El Matador        Rock
# 282                                  Hit the Road Jack        Rock
# 22                                        No One Knows        Rock
# 363                           Wildflowers - Remastered        Rock
# 331                                          I'm A Man        Rock
# ...

# %% [markdown]
# ### Wrapping the 2 method chains into functions

# %%
def combo_df(singsong_cleaned):
    least_popular = singsong_cleaned.sort_values("song_popularity", ascending=True).head(20)
    most_popular = singsong_cleaned.sort_values("song_popularity", ascending=False).head(20)
    sorted_df = singsong_cleaned.sort_values('song_popularity')
    midpoint = len(sorted_df) // 2
    semi_popular = sorted_df.iloc[midpoint-5:midpoint+5]
    combo = pd.concat([most_popular, least_popular, semi_popular], axis=0).sort_values('song_popularity')
    return combo
combo = combo_df(singsong_cleaned)
combo
# Out:
#                                              song_name  song_popularity  \
# 225                                            Querida                4
# 237                                          Chan Chan                7
# 234                                       Besame Mucho                7
# 229                    I Know You Want Me (Calle Ocho)                7
# 338              Psychotic Reaction - Rarities Version                8
# 121                                    Beautiful Girls               10
# 210                                         El Matador               11
# 36                                       The Pretender               11
# 30                                         All My Life               11
# 22                                        No One Knows               13
# 282                                  Hit the Road Jack               13
# 363                           Wildflowers - Remastered               13
# ...

# %%
def process_combo_2(combo):
    combo_2 = (combo.drop_duplicates()
               .assign(genre=['Latin Pop', 'Son cubano', 'Bolero', 'Hip Hop', 'Rock', 'R&B', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Salsa', 'Rock', 'Pop', 'R&B', 'Rock', 'Rock', 'Indie', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Pop', 'Rock', 'Rock', 'Rock', 'Rock', 'Pop', 'Pop', 'Pop', 'Pop', 'R&B', 'Pop', 'Reggae', 'Reggae', 'Hip Hop', 'Hip Hop', 'Pop', 'Pop', 'Hip Hop', 'Reggae'])
               .reindex(columns=['song_name', 'genre', 'song_popularity', 'song_duration_ms', 'acousticness', 'danceability', 'energy', 'key', 'loudness', 'speechiness', 'tempo', 'audio_valence', 'loudness_energy', 'energy_duration']))
    return combo_2
combo_2 = process_combo_2(combo)
combo_2
# Out:
#                                              song_name       genre  \
# 225                                            Querida   Latin Pop
# 237                                          Chan Chan  Son cubano
# 234                                       Besame Mucho      Bolero
# 229                    I Know You Want Me (Calle Ocho)     Hip Hop
# 338              Psychotic Reaction - Rarities Version        Rock
# 121                                    Beautiful Girls         R&B
# 210                                         El Matador        Rock
# 36                                       The Pretender        Rock
# 30                                         All My Life        Rock
# 22                                        No One Knows        Rock
# 282                                  Hit the Road Jack        Rock
# 363                           Wildflowers - Remastered        Rock
# 331                                          I'm A Man        Rock
# ...

# %% [markdown]
# # Analysis

# %%
# Group the dataframe by genre and calculate the mean of song popularity for each group
genre_popularity = combo_2.groupby('genre')['song_popularity'].mean()

# Create a bar chart with genre on the x-axis and mean song popularity on the y-axis
fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(genre_popularity.index, genre_popularity.values)

# Add labels to the chart
ax.set_title('Average Song Popularity by Genre')
ax.set_xlabel('Genre')
ax.set_ylabel('Average Song Popularity')

# Display the chart
plt.show()

# %%
# Filter the dataframe to only include the selected genres
#The filtering is because the other genres don't have enough data points to contribute significant information.
selected_genres = ['Hip Hop', 'Rock', 'Reggae', 'R&B', 'Pop']
selected_data = combo_2[combo_2['genre'].isin(selected_genres)]


sns.violinplot(data=selected_data, x='genre', y='song_popularity')

plt.title('Song Popularity by Genre')
plt.xlabel('Genre')
plt.ylabel('Song Popularity')


plt.show()

# %%
import seaborn as sns

# Select the desired genres
genres = ['Hip Hop', 'Rock', 'Reggae', 'R&B', 'Pop']
combo_filtered = combo_2[combo_2['genre'].isin(genres)]

# Create a pair plot with musical features on the x-axis and y-axis, and genre popularity as hue
sns.pairplot(combo_filtered, x_vars=['acousticness', 'danceability', 'energy', 'loudness', 'speechiness', 'tempo', 'audio_valence', 'loudness_energy', 'energy_duration'], y_vars=['song_popularity'], hue='genre', height=3)

# Display the plot
plt.show()
