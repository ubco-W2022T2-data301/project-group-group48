# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pylab as plt
import seaborn as sns

# %%
music = pd.read_csv("../data/raw/song_data.csv.zip")

# %%
music
# Out:
#                         song_name  song_popularity  song_duration_ms  \
# 0      Boulevard of Broken Dreams               73            262333
# 1                      In The End               66            216933
# 2               Seven Nation Army               76            231733
# 3                      By The Way               74            216933
# 4               How You Remind Me               56            223826
# ...                           ...              ...               ...
# 18830              Let It Breathe               60            159645
# 18831                     Answers               60            205666
# 18832      Sudden Love (Acoustic)               23            182211
# 18833           Gentle on My Mind               55            352280
# 18834                    Up to Me               60            193533
#
#        acousticness  danceability  energy  instrumentalness  key  liveness  \
# ...

# %%
singsong = music.loc[0:499]
singsong
# Out:
#                       song_name  song_popularity  song_duration_ms  \
# 0    Boulevard of Broken Dreams               73            262333
# 1                    In The End               66            216933
# 2             Seven Nation Army               76            231733
# 3                    By The Way               74            216933
# 4             How You Remind Me               56            223826
# ..                          ...              ...               ...
# 495                 China Grove               67            195306
# 496        Foreplay / Long Time               64            467640
# 497              Come Sail Away               59            365000
# 498           Give A Little Bit               72            248173
# 499              Doctor My Eyes               64            199906
#
#      acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0        0.005520         0.496   0.682          0.000029    8    0.0589
# ...

# %%
singsong_cleaned = singsong.drop(['audio_mode','liveness', 'time_signature'], axis=1)
singsong_cleaned
#Cleaning data. I'm cleaning by removing these 3 rows that either had 
#no significant variation or were repetetive to other rows
# Out:
#                       song_name  song_popularity  song_duration_ms  \
# 0    Boulevard of Broken Dreams               73            262333
# 1                    In The End               66            216933
# 2             Seven Nation Army               76            231733
# 3                    By The Way               74            216933
# 4             How You Remind Me               56            223826
# ..                          ...              ...               ...
# 495                 China Grove               67            195306
# 496        Foreplay / Long Time               64            467640
# 497              Come Sail Away               59            365000
# 498           Give A Little Bit               72            248173
# 499              Doctor My Eyes               64            199906
#
#      acousticness  danceability  energy  instrumentalness  key  loudness  \
# 0        0.005520         0.496   0.682          0.000029    8    -4.095
# ...

# %%
singsong_cleaned_1 = singsong_cleaned.dropna(axis=0)
singsong_cleaned_1.shape
# Out:
# (500, 12)

# %%
singsong_cleaned['loudness_energy'] = singsong_cleaned['loudness'] + singsong_cleaned['energy']

# %%
singsong_cleaned # this version of my repository has an additional column combining loudness and energy, the two most correlated elements.
# Out:
#                       song_name  song_popularity  song_duration_ms  \
# 0    Boulevard of Broken Dreams               73            262333
# 1                    In The End               66            216933
# 2             Seven Nation Army               76            231733
# 3                    By The Way               74            216933
# 4             How You Remind Me               56            223826
# ..                          ...              ...               ...
# 495                 China Grove               67            195306
# 496        Foreplay / Long Time               64            467640
# 497              Come Sail Away               59            365000
# 498           Give A Little Bit               72            248173
# 499              Doctor My Eyes               64            199906
#
#      acousticness  danceability  energy  instrumentalness  key  loudness  \
# 0        0.005520         0.496   0.682          0.000029    8    -4.095
# ...

# %%
least_popular = singsong_cleaned.sort_values("song_popularity", ascending=True)
least_popular.head(20) #these are the bottom 20 songs according to popularity
# Out:
#                                             song_name  song_popularity  \
# 225                                           Querida                4
# 229                   I Know You Want Me (Calle Ocho)                7
# 234                                      Besame Mucho                7
# 237                                         Chan Chan                7
# 338             Psychotic Reaction - Rarities Version                8
# 121                                   Beautiful Girls               10
# 36                                      The Pretender               11
# 30                                        All My Life               11
# 210                                        El Matador               11
# 282                                 Hit the Road Jack               13
# 22                                       No One Knows               13
# 363                          Wildflowers - Remastered               13
# ...

# %%
most_popular = singsong_cleaned.sort_values("song_popularity", ascending=False)
most_popular.head(10) #these are the top twenty songs according to popularity
# Out:
#                                           song_name  song_popularity  \
# 61   Taki Taki (with Selena Gomez, Ozuna & Cardi B)               98
# 86                                        I Like It               95
# 85                                             BEBE               95
# 64                 Beautiful (feat. Camila Cabello)               94
# 60                                MIA (feat. Drake)               94
# 70                               Wake Up in the Sky               92
# 101     1, 2, 3 (feat. Jason Derulo & De La Ghetto)               88
# 65                                           Celoso               87
# 67                                     Real Friends               85
# 131                                       All of Me               85
#
#      song_duration_ms  acousticness  danceability  energy  instrumentalness  \
# 61             212500       0.15300         0.841   0.798          0.000003
# ...

# %%
# Define the combination of elements to group by
group_cols = ["song_name","acousticness", "danceability", "energy", "loudness"]

# Group the songs by the combination of elements and calculate the average popularity
grouped = most_popular.groupby(group_cols)["song_popularity"].mean().reset_index()

# Sort the groups by popularity in descending order
sorted_groups = grouped.sort_values(by="song_popularity", ascending=False)

# Display the top 10 most popular groups
sorted_groups.head(10)
# Out:
#                                           song_name  acousticness  \
# 411  Taki Taki (with Selena Gomez, Ozuna & Cardi B)       0.15300
# 31                                             BEBE       0.17200
# 212                                       I Like It       0.09900
# 48                 Beautiful (feat. Camila Cabello)       0.34600
# 282                               MIA (feat. Drake)       0.01430
# 444                              Wake Up in the Sky       0.00381
# 3       1, 2, 3 (feat. Jason Derulo & De La Ghetto)       0.16500
# 95                                           Celoso       0.35200
# 14                                        All of Me       0.92200
# 350                                    Real Friends       0.23500
#
#      danceability  energy  loudness  song_popularity
# 411         0.841   0.798    -4.206             98.0
# 31          0.635   0.902    -3.559             95.0
# 212         0.816   0.726    -3.998             95.0
# ...
