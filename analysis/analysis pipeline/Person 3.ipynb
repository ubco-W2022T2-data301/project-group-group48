# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %% [markdown]
# ### Loading Data

# %%
songdata = pd.read_csv("../../data/raw/song_data.csv.zip")
songdata
# Out:
#                         song_name  song_popularity  song_duration_ms  \
# 0      Boulevard of Broken Dreams               73            262333
# 1                      In The End               66            216933
# 2               Seven Nation Army               76            231733
# 3                      By The Way               74            216933
# 4               How You Remind Me               56            223826
# ...                           ...              ...               ...
# 18830              Let It Breathe               60            159645
# 18831                     Answers               60            205666
# 18832      Sudden Love (Acoustic)               23            182211
# 18833           Gentle on My Mind               55            352280
# 18834                    Up to Me               60            193533
#
#        acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0          0.005520         0.496   0.682          0.000029    8    0.0589
# 1          0.010300         0.542   0.853          0.000000    3    0.1080
# 2          0.008170         0.737   0.463          0.447000    0    0.2550
# 3          0.026400         0.451   0.970          0.003550    0    0.1020
# 4          0.000954         0.447   0.766          0.000000   10    0.1130
# ...             ...           ...     ...               ...  ...       ...
# 18830      0.893000         0.500   0.151          0.000065   11    0.1110
# 18831      0.765000         0.495   0.161          0.000001   11    0.1050
# 18832      0.847000         0.719   0.325          0.000000    0    0.1250
# 18833      0.945000         0.488   0.326          0.015700    3    0.1190
# 18834      0.911000         0.640   0.381          0.000254    4    0.1040
#
#        loudness  audio_mode  speechiness    tempo  time_signature  \
# 0        -4.095           1       0.0294  167.060               4
# 1        -6.407           0       0.0498  105.256               4
# 2        -7.828           1       0.0792  123.881               4
# 3        -4.938           1       0.1070  122.444               4
# 4        -5.065           1       0.0313  172.011               4
# ...         ...         ...          ...      ...             ...
# 18830   -16.107           1       0.0348  113.969               4
# 18831   -14.078           0       0.0301   94.286               4
# 18832   -12.222           1       0.0355  130.534               4
# 18833   -12.020           1       0.0328  106.063               4
# 18834   -11.790           1       0.0302   91.490               4
#
#        audio_valence
# 0              0.474
# 1              0.370
# 2              0.324
# 3              0.198
# 4              0.574
# ...              ...
# 18830          0.300
# 18831          0.265
# 18832          0.286
# 18833          0.323
# 18834          0.581
#
# [18835 rows x 15 columns]

# %% [markdown]
# ### Cleaning Data

# %%
songdata= songdata.drop_duplicates(subset= 'song_name')
songdata
# Out:
#                         song_name  song_popularity  song_duration_ms  \
# 0      Boulevard of Broken Dreams               73            262333
# 1                      In The End               66            216933
# 2               Seven Nation Army               76            231733
# 3                      By The Way               74            216933
# 4               How You Remind Me               56            223826
# ...                           ...              ...               ...
# 18827                  Stay Awake               55            114582
# 18830              Let It Breathe               60            159645
# 18832      Sudden Love (Acoustic)               23            182211
# 18833           Gentle on My Mind               55            352280
# 18834                    Up to Me               60            193533
#
#        acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0          0.005520         0.496   0.682          0.000029    8    0.0589
# 1          0.010300         0.542   0.853          0.000000    3    0.1080
# 2          0.008170         0.737   0.463          0.447000    0    0.2550
# 3          0.026400         0.451   0.970          0.003550    0    0.1020
# 4          0.000954         0.447   0.766          0.000000   10    0.1130
# ...             ...           ...     ...               ...  ...       ...
# 18827      0.898000         0.370   0.136          0.000263    7    0.0999
# 18830      0.893000         0.500   0.151          0.000065   11    0.1110
# 18832      0.847000         0.719   0.325          0.000000    0    0.1250
# 18833      0.945000         0.488   0.326          0.015700    3    0.1190
# 18834      0.911000         0.640   0.381          0.000254    4    0.1040
#
#        loudness  audio_mode  speechiness    tempo  time_signature  \
# 0        -4.095           1       0.0294  167.060               4
# 1        -6.407           0       0.0498  105.256               4
# 2        -7.828           1       0.0792  123.881               4
# 3        -4.938           1       0.1070  122.444               4
# 4        -5.065           1       0.0313  172.011               4
# ...         ...         ...          ...      ...             ...
# 18827   -13.528           1       0.0433  146.081               4
# 18830   -16.107           1       0.0348  113.969               4
# 18832   -12.222           1       0.0355  130.534               4
# 18833   -12.020           1       0.0328  106.063               4
# 18834   -11.790           1       0.0302   91.490               4
#
#        audio_valence
# 0             0.4740
# 1             0.3700
# 2             0.3240
# 3             0.1980
# 4             0.5740
# ...              ...
# 18827         0.0592
# 18830         0.3000
# 18832         0.2860
# 18833         0.3230
# 18834         0.5810
#
# [13070 rows x 15 columns]

# %%
songdata= songdata.loc [0:510]
songdata
#this step returns the first 500 unique songs.
# Out:
#                               song_name  song_popularity  song_duration_ms  \
# 0            Boulevard of Broken Dreams               73            262333
# 1                            In The End               66            216933
# 2                     Seven Nation Army               76            231733
# 3                            By The Way               74            216933
# 4                     How You Remind Me               56            223826
# ..                                  ...              ...               ...
# 506  Life In The Fast Lane - Remastered               72            286219
# 507                    Life's Been Good               69            536226
# 508                   Locomotive Breath               60            266013
# 509                    Like A Hurricane               47            501213
# 510                        Livin' Thing               68            212306
#
#      acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0        0.005520         0.496   0.682          0.000029    8    0.0589
# 1        0.010300         0.542   0.853          0.000000    3    0.1080
# 2        0.008170         0.737   0.463          0.447000    0    0.2550
# 3        0.026400         0.451   0.970          0.003550    0    0.1020
# 4        0.000954         0.447   0.766          0.000000   10    0.1130
# ..            ...           ...     ...               ...  ...       ...
# 506      0.096600         0.667   0.755          0.000069    9    0.0523
# 507      0.250000         0.505   0.476          0.009150    2    0.1130
# 508      0.412000         0.693   0.528          0.003550   11    0.0563
# 509      0.012900         0.423   0.834          0.001130    9    0.1640
# 510      0.583000         0.549   0.651          0.000000    0    0.1210
#
#      loudness  audio_mode  speechiness    tempo  time_signature  audio_valence
# 0      -4.095           1       0.0294  167.060               4          0.474
# 1      -6.407           0       0.0498  105.256               4          0.370
# 2      -7.828           1       0.0792  123.881               4          0.324
# 3      -4.938           1       0.1070  122.444               4          0.198
# 4      -5.065           1       0.0313  172.011               4          0.574
# ..        ...         ...          ...      ...             ...            ...
# 506    -7.246           1       0.0690  109.535               4          0.883
# 507   -12.897           1       0.0711   99.310               4          0.542
# 508   -13.094           0       0.0855  124.573               4          0.339
# 509    -5.498           0       0.0370  113.876               4          0.606
# 510    -7.097           1       0.0323  122.818               4          0.368
#
# [500 rows x 15 columns]

# %%
songdata_cleaned = songdata.drop(['audio_mode', 'time_signature'],axis=1)
songdata_cleaned
# Out:
#                               song_name  song_popularity  song_duration_ms  \
# 0            Boulevard of Broken Dreams               73            262333
# 1                            In The End               66            216933
# 2                     Seven Nation Army               76            231733
# 3                            By The Way               74            216933
# 4                     How You Remind Me               56            223826
# ..                                  ...              ...               ...
# 506  Life In The Fast Lane - Remastered               72            286219
# 507                    Life's Been Good               69            536226
# 508                   Locomotive Breath               60            266013
# 509                    Like A Hurricane               47            501213
# 510                        Livin' Thing               68            212306
#
#      acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0        0.005520         0.496   0.682          0.000029    8    0.0589
# 1        0.010300         0.542   0.853          0.000000    3    0.1080
# 2        0.008170         0.737   0.463          0.447000    0    0.2550
# 3        0.026400         0.451   0.970          0.003550    0    0.1020
# 4        0.000954         0.447   0.766          0.000000   10    0.1130
# ..            ...           ...     ...               ...  ...       ...
# 506      0.096600         0.667   0.755          0.000069    9    0.0523
# 507      0.250000         0.505   0.476          0.009150    2    0.1130
# 508      0.412000         0.693   0.528          0.003550   11    0.0563
# 509      0.012900         0.423   0.834          0.001130    9    0.1640
# 510      0.583000         0.549   0.651          0.000000    0    0.1210
#
#      loudness  speechiness    tempo  audio_valence
# 0      -4.095       0.0294  167.060          0.474
# 1      -6.407       0.0498  105.256          0.370
# 2      -7.828       0.0792  123.881          0.324
# 3      -4.938       0.1070  122.444          0.198
# 4      -5.065       0.0313  172.011          0.574
# ..        ...          ...      ...            ...
# 506    -7.246       0.0690  109.535          0.883
# 507   -12.897       0.0711   99.310          0.542
# 508   -13.094       0.0855  124.573          0.339
# 509    -5.498       0.0370  113.876          0.606
# 510    -7.097       0.0323  122.818          0.368
#
# [500 rows x 13 columns]

# %%
songdata_cleaned = songdata.dropna(axis=0)
songdata_cleaned.shape
# Out:
# (500, 15)

# %%
songdata_cleaned.nunique(axis=0) 
# This step allows me to identify how many unique values I have for each element and recognize any duplicates.
# Out:
# song_name           500
# song_popularity      70
# song_duration_ms    495
# acousticness        444
# danceability        331
# energy              350
# instrumentalness    313
# key                  12
# liveness            339
# loudness            491
# audio_mode            2
# speechiness         346
# tempo               497
# time_signature        4
# audio_valence       367
# dtype: int64

# %% [markdown]
# ### In this data cleaning step, I have shortened our dataset to include only the first 500 rows/songs which are the only ones we will be using in our analysis. I have also removed/dropped the audio mode and time signiture columuns because they either had very little variation or no variation at all.

# %% [markdown]
# ## Processing Data

# %%
songdata_sorted = songdata.sort_values(by='song_popularity', ascending=False).reset_index()
songdata_sorted
# Out:
#      index                                       song_name  song_popularity  \
# 0       61  Taki Taki (with Selena Gomez, Ozuna & Cardi B)               98
# 1       86                                       I Like It               95
# 2       85                                            BEBE               95
# 3       64                Beautiful (feat. Camila Cabello)               94
# 4       60                               MIA (feat. Drake)               94
# ..     ...                                             ...              ...
# 495    121                                 Beautiful Girls               10
# 496    338           Psychotic Reaction - Rarities Version                8
# 497    234                                    Besame Mucho                7
# 498    237                                       Chan Chan                7
# 499    225                                         Querida                4
#
#      song_duration_ms  acousticness  danceability  energy  instrumentalness  \
# 0              212500      0.153000         0.841   0.798          0.000003
# 1              253390      0.099000         0.816   0.726          0.000000
# 2              217822      0.172000         0.635   0.902          0.000000
# 3              180000      0.346000         0.638   0.717          0.000000
# 4              210367      0.014300         0.818   0.540          0.000512
# ..                ...           ...           ...     ...               ...
# 495            241933      0.159000         0.745   0.666          0.000000
# 496            189848      0.000288         0.355   0.761          0.014100
# 497            181960      0.701000         0.707   0.408          0.000000
# 498            257213      0.830000         0.507   0.423          0.009160
# 499            319560      0.318000         0.522   0.526          0.000000
#
#      key  liveness  loudness  audio_mode  speechiness    tempo  \
# 0      1    0.0618    -4.206           0       0.2290   95.948
# 1      5    0.3720    -3.998           0       0.1290  136.048
# 2      0    0.1250    -3.559           1       0.1090  102.063
# 3      2    0.1050    -4.722           1       0.0337  100.027
# 4      6    0.0990    -6.350           0       0.0544   97.064
# ..   ...       ...       ...         ...          ...      ...
# 495    9    0.3020    -5.899           1       0.0566  129.995
# 496   11    0.1890    -6.309           1       0.0978  165.209
# 497    5    0.1050   -12.776           0       0.0366  126.399
# 498    2    0.0973   -14.187           0       0.0332   82.809
# 499    2    0.1160    -6.361           1       0.0259   90.020
#
#      time_signature  audio_valence
# 0                 4          0.591
# 1                 4          0.650
# 2                 4          0.286
# 3                 4          0.249
# 4                 4          0.174
# ..              ...            ...
# 495               4          0.708
# 496               4          0.685
# 497               4          0.843
# 498               4          0.701
# 499               4          0.430
#
# [500 rows x 16 columns]

# %%
def multiply_columns(row):
    return row['energy'] * row['loudness']

songdata_sorted['Loud_Enrgy_Prod'] = songdata_sorted.aggregate(multiply_columns, axis=1) # This creates a new column that multiplies each loudness value to the corresponding energy value
songdata_sorted
# Out:
#      index                                       song_name  song_popularity  \
# 0       61  Taki Taki (with Selena Gomez, Ozuna & Cardi B)               98
# 1       86                                       I Like It               95
# 2       85                                            BEBE               95
# 3       64                Beautiful (feat. Camila Cabello)               94
# 4       60                               MIA (feat. Drake)               94
# ..     ...                                             ...              ...
# 495    121                                 Beautiful Girls               10
# 496    338           Psychotic Reaction - Rarities Version                8
# 497    234                                    Besame Mucho                7
# 498    237                                       Chan Chan                7
# 499    225                                         Querida                4
#
#      song_duration_ms  acousticness  danceability  energy  instrumentalness  \
# 0              212500      0.153000         0.841   0.798          0.000003
# 1              253390      0.099000         0.816   0.726          0.000000
# 2              217822      0.172000         0.635   0.902          0.000000
# 3              180000      0.346000         0.638   0.717          0.000000
# 4              210367      0.014300         0.818   0.540          0.000512
# ..                ...           ...           ...     ...               ...
# 495            241933      0.159000         0.745   0.666          0.000000
# 496            189848      0.000288         0.355   0.761          0.014100
# 497            181960      0.701000         0.707   0.408          0.000000
# 498            257213      0.830000         0.507   0.423          0.009160
# 499            319560      0.318000         0.522   0.526          0.000000
#
#      key  liveness  loudness  audio_mode  speechiness    tempo  \
# 0      1    0.0618    -4.206           0       0.2290   95.948
# 1      5    0.3720    -3.998           0       0.1290  136.048
# 2      0    0.1250    -3.559           1       0.1090  102.063
# 3      2    0.1050    -4.722           1       0.0337  100.027
# 4      6    0.0990    -6.350           0       0.0544   97.064
# ..   ...       ...       ...         ...          ...      ...
# 495    9    0.3020    -5.899           1       0.0566  129.995
# 496   11    0.1890    -6.309           1       0.0978  165.209
# 497    5    0.1050   -12.776           0       0.0366  126.399
# 498    2    0.0973   -14.187           0       0.0332   82.809
# 499    2    0.1160    -6.361           1       0.0259   90.020
#
#      time_signature  audio_valence  Loud_Enrgy_Prod
# 0                 4          0.591        -3.356388
# 1                 4          0.650        -2.902548
# 2                 4          0.286        -3.210218
# 3                 4          0.249        -3.385674
# 4                 4          0.174        -3.429000
# ..              ...            ...              ...
# 495               4          0.708        -3.928734
# 496               4          0.685        -4.801149
# 497               4          0.843        -5.212608
# 498               4          0.701        -6.001101
# 499               4          0.430        -3.345886
#
# [500 rows x 17 columns]

# %% [markdown]
# ### In this processing step, I have ranked my data by song popularity in descending order and created a new variable Loud_Enrgy_Prod that is an aggregate of energy and loudness. I chose to agreegate these two variables because I found in my initaial analysis that loudness and energy  had the biggest correlation

# %% [markdown]
# # Wrangling

# %%
def classify(songdata_sorted):
    songdata_top = (songdata_sorted.head(20)
               .assign(genre=['Reggae', 'Hip Hop', 'Pop', 'Pop', 'Hip Hop', 'Pop', 'Hip Hop', 'Reggae', 'Reggae', 'Pop', 'R&B', 'Pop', 'Pop', 'Pop', 'Rock', 'Pop', 'Rock', 'R&B', 'Rock', 'Rock'])
               .reindex(columns=['song_name', 'genre', 'song_popularity', 'song_duration_ms', 'acousticness', 'danceability', 'energy','instrumentalness', 'key', 'liveness','loudness', 'speechiness', 'tempo', 'audio_valence', 'Loud_Enrgy_Prod']))
    return songdata_top
songdata_top = classify(songdata_sorted)
songdata_top
# Out:
#                                          song_name    genre  song_popularity  \
# 0   Taki Taki (with Selena Gomez, Ozuna & Cardi B)   Reggae               98
# 1                                        I Like It  Hip Hop               95
# 2                                             BEBE      Pop               95
# 3                 Beautiful (feat. Camila Cabello)      Pop               94
# 4                                MIA (feat. Drake)  Hip Hop               94
# 5                               Wake Up in the Sky      Pop               92
# 6      1, 2, 3 (feat. Jason Derulo & De La Ghetto)  Hip Hop               88
# 7                                           Celoso   Reggae               87
# 8                                     Real Friends   Reggae               85
# 9                                        All of Me      Pop               85
# 10                                  Hips Don't Lie      R&B               84
# 11                                 Pumped Up Kicks      Pop               84
# 12                 Finesse (Remix) [feat. Cardi B]      Pop               84
# 13                                 Highway to Hell      Pop               83
# 14                   Hotel California - Remastered     Rock               83
# 15                                       Está Rico      Pop               83
# 16                              How to Save a Life     Rock               83
# 17                              If I Ain't Got You      R&B               81
# 18                                   Fortunate Son     Rock               81
# 19                                   Bleeding Love     Rock               81
#
#     song_duration_ms  acousticness  danceability  energy  instrumentalness  \
# 0             212500       0.15300         0.841   0.798          0.000003
# 1             253390       0.09900         0.816   0.726          0.000000
# 2             217822       0.17200         0.635   0.902          0.000000
# 3             180000       0.34600         0.638   0.717          0.000000
# 4             210367       0.01430         0.818   0.540          0.000512
# 5             204664       0.00381         0.800   0.578          0.000000
# 6             201526       0.16500         0.792   0.895          0.000000
# 7             179693       0.35200         0.746   0.703          0.000000
# 8             223583       0.23500         0.701   0.512          0.000005
# 9             269560       0.92200         0.422   0.264          0.000000
# 10            218093       0.28400         0.778   0.824          0.000000
# 11            239600       0.14500         0.733   0.710          0.115000
# 12            217288       0.01850         0.704   0.859          0.000000
# 13            208400       0.05910         0.573   0.913          0.001730
# 14            391376       0.00574         0.579   0.508          0.000494
# 15            215151       0.26600         0.817   0.740          0.000000
# 16            262533       0.26900         0.640   0.743          0.000000
# 17            228706       0.60300         0.609   0.445          0.000007
# 18            140773       0.20100         0.640   0.663          0.008060
# 19            262466       0.18800         0.638   0.656          0.000000
#
#     key  liveness  loudness  speechiness    tempo  audio_valence  \
# 0     1    0.0618    -4.206       0.2290   95.948          0.591
# 1     5    0.3720    -3.998       0.1290  136.048          0.650
# 2     0    0.1250    -3.559       0.1090  102.063          0.286
# 3     2    0.1050    -4.722       0.0337  100.027          0.249
# 4     6    0.0990    -6.350       0.0544   97.064          0.174
# 5     4    0.3590    -5.144       0.0485  143.010          0.367
# 6     1    0.0501    -3.112       0.0589   94.968          0.794
# 7     4    0.3310    -4.179       0.1070  166.043          0.667
# 8     0    0.1350    -6.869       0.0969   91.947          0.663
# 9     8    0.1320    -7.064       0.0322  119.930          0.331
# 10   10    0.4050    -5.892       0.0712  100.024          0.756
# 11    5    0.0956    -5.849       0.0292  127.975          0.965
# 12    5    0.0215    -4.877       0.0996  105.115          0.926
# 13    6    0.1560    -4.793       0.1320  115.715          0.422
# 14    2    0.0575    -9.484       0.0270  147.125          0.609
# 15   11    0.0992    -4.566       0.2830  130.040          0.674
# 16   10    0.1010    -4.080       0.0379  122.035          0.361
# 17    7    0.1040    -9.129       0.1060  118.393          0.166
# 18    0    0.1520    -7.516       0.0374  132.770          0.663
# 19    5    0.1460    -5.886       0.0357  104.036          0.225
#
#     Loud_Enrgy_Prod
# 0         -3.356388
# 1         -2.902548
# 2         -3.210218
# 3         -3.385674
# 4         -3.429000
# 5         -2.973232
# 6         -2.785240
# 7         -2.937837
# 8         -3.516928
# 9         -1.864896
# 10        -4.855008
# 11        -4.152790
# 12        -4.189343
# 13        -4.376009
# 14        -4.817872
# 15        -3.378840
# 16        -3.031440
# 17        -4.062405
# 18        -4.983108
# 19        -3.861216

# %%
def classify(songdata_sorted):
    songdata_bottom = songdata_sorted.tail(20).sort_values(by=['song_popularity'], ascending = True)\
        .assign(genre=['Latin Pop', 'Son cubano', 'Bolero', 'Hip Hop', 'Rock', 'R&B', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Salsa', 'Rock', 'Pop', 'R&B', 'Rock'])\
        .reindex(columns=['song_name', 'genre', 'song_popularity', 'song_duration_ms', 'acousticness', 'danceability', 'energy','instrumentalness','key', 'liveness','loudness', 'speechiness', 'tempo', 'audio_valence', 'Loud_Enrgy_Prod'])
    return songdata_bottom

songdata_bottom = classify(songdata_sorted)
songdata_bottom
# Out:
#                                             song_name       genre  \
# 499                                           Querida   Latin Pop
# 497                                      Besame Mucho  Son cubano
# 498                                         Chan Chan      Bolero
# 496             Psychotic Reaction - Rarities Version     Hip Hop
# 495                                   Beautiful Girls        Rock
# 494                                     The Pretender         R&B
# 493                                        El Matador        Rock
# 492                                       All My Life        Rock
# 491                                      No One Knows        Rock
# 490                          Wildflowers - Remastered        Rock
# 489                                 Hit the Road Jack        Rock
# 488                                         I'm A Man        Rock
# 487  I'm Waiting For The Man - Album Version (Stereo)        Rock
# 486            Jumpin' Jack Flash - Mono / Remastered        Rock
# 485                                     Solsbury Hill        Rock
# 484                            La Vida Es Un Carnaval       Salsa
# 483                                            Blurry        Rock
# 482                                   La Camisa Negra         Pop
# 481                                        Proud Mary         R&B
# 480                                          96 Tears        Rock
#
#      song_popularity  song_duration_ms  acousticness  danceability  energy  \
# 499                4            319560      0.318000         0.522   0.526
# 497                7            181960      0.701000         0.707   0.408
# 498                7            257213      0.830000         0.507   0.423
# 496                8            189848      0.000288         0.355   0.761
# 495               10            241933      0.159000         0.745   0.666
# 494               11            269373      0.000917         0.433   0.959
# 493               11            277600      0.030600         0.566   0.911
# 492               11            262733      0.000194         0.582   0.597
# 491               13            255066      0.013700         0.518   0.538
# 490               13            216573      0.762000         0.609   0.368
# 489               13            120173      0.714000         0.599   0.704
# 488               14            176160      0.038000         0.550   0.929
# 487               16            279520      0.025000         0.682   0.621
# 486               21            219466      0.047000         0.600   0.897
# 485               21            262600      0.378000         0.678   0.622
# 484               24            275253      0.439000         0.820   0.717
# 483               28            303920      0.010200         0.440   0.932
# 482               29            216706      0.083800         0.751   0.731
# 481               30            187213      0.130000         0.699   0.641
# 480               30            177426      0.058600         0.680   0.507
#
#      instrumentalness  key  liveness  loudness  speechiness    tempo  \
# 499          0.000000    2    0.1160    -6.361       0.0259   90.020
# 497          0.000000    5    0.1050   -12.776       0.0366  126.399
# 498          0.009160    2    0.0973   -14.187       0.0332   82.809
# 496          0.014100   11    0.1890    -6.309       0.0978  165.209
# 495          0.000000    9    0.3020    -5.899       0.0566  129.995
# 494          0.000000    9    0.0280    -4.040       0.0431  172.984
# 493          0.024700    4    0.0574    -9.458       0.0791  193.538
# 492          0.000273    5    0.5170    -5.671       0.0512  167.738
# 491          0.000398    0    0.1410    -5.818       0.0486  170.953
# 490          0.000006   10    0.3350   -13.338       0.0294   90.373
# 489          0.000000    8    0.5210    -8.566       0.2430  173.043
# 488          0.000000    9    0.1350    -5.765       0.0815  129.011
# 487          0.852000    7    0.1530    -9.653       0.0451  125.910
# 486          0.727000    3    0.0672    -7.275       0.0477  137.375
# 485          0.000953   11    0.3630    -8.875       0.0301  102.229
# 484          0.001070    8    0.2360    -6.191       0.0722  104.005
# 483          0.000000    3    0.1420    -4.488       0.0584  157.438
# 482          0.000000    6    0.0556    -4.419       0.0308   97.007
# 481          0.000218    2    0.0601    -7.564       0.0289  120.745
# 480          0.000006    7    0.0754    -5.929       0.0336  123.470
#
#      audio_valence  Loud_Enrgy_Prod
# 499          0.430        -3.345886
# 497          0.843        -5.212608
# 498          0.701        -6.001101
# 496          0.685        -4.801149
# 495          0.708        -3.928734
# 494          0.365        -3.874360
# 493          0.638        -8.616238
# 492          0.674        -3.385587
# 491          0.687        -3.130084
# 490          0.618        -4.908384
# 489          0.950        -6.030464
# 488          0.643        -5.355685
# 487          0.861        -5.994513
# 486          0.676        -6.525675
# 485          0.471        -5.520250
# 484          0.843        -4.438947
# 483          0.495        -4.182816
# 482          0.973        -3.230289
# 481          0.728        -4.848524
# 480          0.854        -3.006003

# %% [markdown]
# ### In this wrangling step, I have created method chains in which I seperate the top 15 popular songs and the least 15 popular songs, reindex them, and I add a new colum that classifies the songs by music genre.

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Research Question #1

# %%
custom_palette = sns.color_palette("Oranges_r", 20) + sns.color_palette("Reds", 20)

# To compute the correlation matrix, we use 
corr = songdata_cleaned.corr(numeric_only=True)

plt.figure(figsize=(10,8))
sns.heatmap(corr, 
            xticklabels=corr.columns, 
            yticklabels=corr.columns, 
            annot=True, 
            cmap=custom_palette)
plt.yticks(rotation=0)
plt.show()

# %%
sns.regplot(x="Loud_Enrgy_Prod", y="song_popularity", data=songdata_top, color= "b").set( title = "Popularity vs Loudness*Energy - Top Songs")
# Out:
# [Text(0.5, 1.0, 'Popularity vs Loudness*Energy - Top Songs')]

# %%
sns.regplot(x="Loud_Enrgy_Prod", y="song_popularity", data=songdata_bottom, color= "b").set( title = "Popularity vs Loudness*Energy - Bottom Songs")
# Out:
# [Text(0.5, 1.0, 'Popularity vs Loudness*Energy - Bottom Songs')]

# %% [markdown]
# ### The visualizations above are scatter plots with best fit lines to show the relationship between my new variable (Loud_Enrgy_Prod) and song popularity. My rational behind these plots was to observe a relationship between the two factors that were most correlated (loudness and energy) and songpopularity to infer on their relavance. The graphs show a positive relationship with song popularity for the top 15 popular songs and a negative relationship for the bottom 15 popular songs. While these results seem logicall, it is important to acknowledge that my sample is on 30 songs and could be too small to make any significant or accurate inferences about the relationship between songpopularity, energy and loudness.

# %% [markdown]
# ## Research Question #2

# %%
concatenated_df = pd.concat([songdata_top, songdata_bottom], ignore_index=True)
concatenated_df
# Out:
#                                            song_name       genre  \
# 0     Taki Taki (with Selena Gomez, Ozuna & Cardi B)      Reggae
# 1                                          I Like It     Hip Hop
# 2                                               BEBE         Pop
# 3                   Beautiful (feat. Camila Cabello)         Pop
# 4                                  MIA (feat. Drake)     Hip Hop
# 5                                 Wake Up in the Sky         Pop
# 6        1, 2, 3 (feat. Jason Derulo & De La Ghetto)     Hip Hop
# 7                                             Celoso      Reggae
# 8                                       Real Friends      Reggae
# 9                                          All of Me         Pop
# 10                                    Hips Don't Lie         R&B
# 11                                   Pumped Up Kicks         Pop
# 12                   Finesse (Remix) [feat. Cardi B]         Pop
# 13                                   Highway to Hell         Pop
# 14                     Hotel California - Remastered        Rock
# 15                                         Está Rico         Pop
# 16                                How to Save a Life        Rock
# 17                                If I Ain't Got You         R&B
# 18                                     Fortunate Son        Rock
# 19                                     Bleeding Love        Rock
# 20                                           Querida   Latin Pop
# 21                                      Besame Mucho  Son cubano
# 22                                         Chan Chan      Bolero
# 23             Psychotic Reaction - Rarities Version     Hip Hop
# 24                                   Beautiful Girls        Rock
# 25                                     The Pretender         R&B
# 26                                        El Matador        Rock
# 27                                       All My Life        Rock
# 28                                      No One Knows        Rock
# 29                          Wildflowers - Remastered        Rock
# 30                                 Hit the Road Jack        Rock
# 31                                         I'm A Man        Rock
# 32  I'm Waiting For The Man - Album Version (Stereo)        Rock
# 33            Jumpin' Jack Flash - Mono / Remastered        Rock
# 34                                     Solsbury Hill        Rock
# 35                            La Vida Es Un Carnaval       Salsa
# 36                                            Blurry        Rock
# 37                                   La Camisa Negra         Pop
# 38                                        Proud Mary         R&B
# 39                                          96 Tears        Rock
#
#     song_popularity  song_duration_ms  acousticness  danceability  energy  \
# 0                98            212500      0.153000         0.841   0.798
# 1                95            253390      0.099000         0.816   0.726
# 2                95            217822      0.172000         0.635   0.902
# 3                94            180000      0.346000         0.638   0.717
# 4                94            210367      0.014300         0.818   0.540
# 5                92            204664      0.003810         0.800   0.578
# 6                88            201526      0.165000         0.792   0.895
# 7                87            179693      0.352000         0.746   0.703
# 8                85            223583      0.235000         0.701   0.512
# 9                85            269560      0.922000         0.422   0.264
# 10               84            218093      0.284000         0.778   0.824
# 11               84            239600      0.145000         0.733   0.710
# 12               84            217288      0.018500         0.704   0.859
# 13               83            208400      0.059100         0.573   0.913
# 14               83            391376      0.005740         0.579   0.508
# 15               83            215151      0.266000         0.817   0.740
# 16               83            262533      0.269000         0.640   0.743
# 17               81            228706      0.603000         0.609   0.445
# 18               81            140773      0.201000         0.640   0.663
# 19               81            262466      0.188000         0.638   0.656
# 20                4            319560      0.318000         0.522   0.526
# 21                7            181960      0.701000         0.707   0.408
# 22                7            257213      0.830000         0.507   0.423
# 23                8            189848      0.000288         0.355   0.761
# 24               10            241933      0.159000         0.745   0.666
# 25               11            269373      0.000917         0.433   0.959
# 26               11            277600      0.030600         0.566   0.911
# 27               11            262733      0.000194         0.582   0.597
# 28               13            255066      0.013700         0.518   0.538
# 29               13            216573      0.762000         0.609   0.368
# 30               13            120173      0.714000         0.599   0.704
# 31               14            176160      0.038000         0.550   0.929
# 32               16            279520      0.025000         0.682   0.621
# 33               21            219466      0.047000         0.600   0.897
# 34               21            262600      0.378000         0.678   0.622
# 35               24            275253      0.439000         0.820   0.717
# 36               28            303920      0.010200         0.440   0.932
# 37               29            216706      0.083800         0.751   0.731
# 38               30            187213      0.130000         0.699   0.641
# 39               30            177426      0.058600         0.680   0.507
#
#     instrumentalness  key  liveness  loudness  speechiness    tempo  \
# 0           0.000003    1    0.0618    -4.206       0.2290   95.948
# 1           0.000000    5    0.3720    -3.998       0.1290  136.048
# 2           0.000000    0    0.1250    -3.559       0.1090  102.063
# 3           0.000000    2    0.1050    -4.722       0.0337  100.027
# 4           0.000512    6    0.0990    -6.350       0.0544   97.064
# 5           0.000000    4    0.3590    -5.144       0.0485  143.010
# 6           0.000000    1    0.0501    -3.112       0.0589   94.968
# 7           0.000000    4    0.3310    -4.179       0.1070  166.043
# 8           0.000005    0    0.1350    -6.869       0.0969   91.947
# 9           0.000000    8    0.1320    -7.064       0.0322  119.930
# 10          0.000000   10    0.4050    -5.892       0.0712  100.024
# 11          0.115000    5    0.0956    -5.849       0.0292  127.975
# 12          0.000000    5    0.0215    -4.877       0.0996  105.115
# 13          0.001730    6    0.1560    -4.793       0.1320  115.715
# 14          0.000494    2    0.0575    -9.484       0.0270  147.125
# 15          0.000000   11    0.0992    -4.566       0.2830  130.040
# 16          0.000000   10    0.1010    -4.080       0.0379  122.035
# 17          0.000007    7    0.1040    -9.129       0.1060  118.393
# 18          0.008060    0    0.1520    -7.516       0.0374  132.770
# 19          0.000000    5    0.1460    -5.886       0.0357  104.036
# 20          0.000000    2    0.1160    -6.361       0.0259   90.020
# 21          0.000000    5    0.1050   -12.776       0.0366  126.399
# 22          0.009160    2    0.0973   -14.187       0.0332   82.809
# 23          0.014100   11    0.1890    -6.309       0.0978  165.209
# 24          0.000000    9    0.3020    -5.899       0.0566  129.995
# 25          0.000000    9    0.0280    -4.040       0.0431  172.984
# 26          0.024700    4    0.0574    -9.458       0.0791  193.538
# 27          0.000273    5    0.5170    -5.671       0.0512  167.738
# 28          0.000398    0    0.1410    -5.818       0.0486  170.953
# 29          0.000006   10    0.3350   -13.338       0.0294   90.373
# 30          0.000000    8    0.5210    -8.566       0.2430  173.043
# 31          0.000000    9    0.1350    -5.765       0.0815  129.011
# 32          0.852000    7    0.1530    -9.653       0.0451  125.910
# 33          0.727000    3    0.0672    -7.275       0.0477  137.375
# 34          0.000953   11    0.3630    -8.875       0.0301  102.229
# 35          0.001070    8    0.2360    -6.191       0.0722  104.005
# 36          0.000000    3    0.1420    -4.488       0.0584  157.438
# 37          0.000000    6    0.0556    -4.419       0.0308   97.007
# 38          0.000218    2    0.0601    -7.564       0.0289  120.745
# 39          0.000006    7    0.0754    -5.929       0.0336  123.470
#
#     audio_valence  Loud_Enrgy_Prod
# 0           0.591        -3.356388
# 1           0.650        -2.902548
# 2           0.286        -3.210218
# 3           0.249        -3.385674
# 4           0.174        -3.429000
# 5           0.367        -2.973232
# 6           0.794        -2.785240
# 7           0.667        -2.937837
# 8           0.663        -3.516928
# 9           0.331        -1.864896
# 10          0.756        -4.855008
# 11          0.965        -4.152790
# 12          0.926        -4.189343
# 13          0.422        -4.376009
# 14          0.609        -4.817872
# 15          0.674        -3.378840
# 16          0.361        -3.031440
# 17          0.166        -4.062405
# 18          0.663        -4.983108
# 19          0.225        -3.861216
# 20          0.430        -3.345886
# 21          0.843        -5.212608
# 22          0.701        -6.001101
# 23          0.685        -4.801149
# 24          0.708        -3.928734
# 25          0.365        -3.874360
# 26          0.638        -8.616238
# 27          0.674        -3.385587
# 28          0.687        -3.130084
# 29          0.618        -4.908384
# 30          0.950        -6.030464
# 31          0.643        -5.355685
# 32          0.861        -5.994513
# 33          0.676        -6.525675
# 34          0.471        -5.520250
# 35          0.843        -4.438947
# 36          0.495        -4.182816
# 37          0.973        -3.230289
# 38          0.728        -4.848524
# 39          0.854        -3.006003

# %%
grouped = concatenated_df.groupby('genre')['song_popularity'].mean()
plt.barh(grouped.index, grouped.values)

plt.xlabel('Mean Song Popularity')
plt.ylabel('Genre')
plt.title('Average Song Popularity by Genre')

plt.show()

# %% [markdown]
# ### This bar plot shows the mean song popularity for each genre in the top 15 and bottom 15 songs of the dataset. It is important to note that the samples for some of the genres are small, which means that the results may not be entirely accurate. Additionally, the distribution of genres in the dataset is uneven, with 16 rock songs and 9 pop songs, while only 4 hip hop songs, 4 R&Bs, 3 reggae, and only 1 bolero, 1 latin pop,1 Salsa and 1 son cubano.
# ### Despite these limitations, the bar plot does show some interesting trends. The highest mean song popularity for both the top 15 and bottom 15 songs was found in the Reggae genre.This is particularly interesting given that there were only 3 samples of this genre.  The Pop genre was a close second followed by the Hip Hop gengre, R&B and Rock respectively. Naturally, since their sample size were much smaller, the Bolero, Latin Pop and Son Cuban genres had the least mean song popularity.
# ### Overall, while the sample sizes for some of the genres are small, the bar plot still provides some insights into the relative popularity of different genres in the dataset. However, it is important to interpret these results with caution given the uneven distribution of genres in the dataset. Further analysis with a larger sample size may be necessary to draw more accurate conclusions.

# %%
reggae_data = concatenated_df.loc[concatenated_df['genre'] == 'Reggae', ['instrumentalness', 'key','loudness','Loud_Enrgy_Prod']]
pop_data = concatenated_df.loc[concatenated_df['genre'] == 'Pop', ['instrumentalness', 'key','loudness','Loud_Enrgy_Prod']]
hip_hop_data =concatenated_df.loc[concatenated_df['genre'] == 'Hip Hop', ['instrumentalness', 'key','loudness','Loud_Enrgy_Prod']]

# Create a list of the dataframes and the genre labels
data = [reggae_data, pop_data, hip_hop_data]
labels = ['Reggae', 'Pop', 'Hip Hop']

# Create a figure with subplots for each musical element
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10,10))

# Loop through each element and plot a box plot for each genre
for i, element in enumerate(['instrumentalness', 'key','loudness','Loud_Enrgy_Prod']):
    row = i // 2
    col = i % 2
    data_to_plot = [genre_data[element] for genre_data in data]
    axs[row, col].boxplot(data_to_plot)
    axs[row, col].set_title(element)
    axs[row, col].set_xticklabels(labels)

plt.tight_layout()
plt.show()

# %%
### In the scatter plots above, I observe the relationship between

# %% [markdown]
# # Import Method Chain

# %%
from analysis import project_functions3 # This is called a relative import
df = project_functions3.load_and_process("/Users/Annabellengarambe/Desktop/DATA_301/project-group-group48/data/raw/song_data.csv.zip")
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[313], line 1
# ----> 1 from analysis import project_functions3 # This is called a relative import
#       2 ##df = project_functions3.load_and_process("/Users/Annabellengarambe/Desktop/DATA_301/project-group-group48/data/raw/song_data.csv.zip")
#       3 ##df
#
# ModuleNotFoundError: No module named 'analysis'
