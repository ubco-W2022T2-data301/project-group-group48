# %% [markdown]
# # Tobi Ogunbote

# %% [markdown]
# ## Research question/interests
#
# ## Are songs with repeated verses or choruses considered more catchy or popular than songs without?
#
# To be able to answer this question, I will look at the lyrics of all the songs in our data set and pick out which songs have repeated verses or choruses and observe the position of that song in our list. If the position is high up then it is popular and if it is low, then it is not as popular. I am aware this will take a long time to go through, but if I can find a way to make a code for checking repeated words in a song, then this would help me sift through the songs faster and get to my answer quicker.
#
#
# ## Are there specific genres of music that are more popular than others?
#
# I think that by including columns for each of the many musical genres—such as pop, hip-hop, punk, etc.—I will be able to provide the solution to this question. After conducting some research on what people believe to be a popular musical genre, I will be able to display the results in a column using this column and a rating for each one.

# %%
import numpy as np
import pandas as pd

# %%
music = pd.read_csv("../data/raw/song_data.csv.zip")

# %%
music
# Out:
#                         song_name  song_popularity  song_duration_ms  \
# 0      Boulevard of Broken Dreams               73            262333
# 1                      In The End               66            216933
# 2               Seven Nation Army               76            231733
# 3                      By The Way               74            216933
# 4               How You Remind Me               56            223826
# ...                           ...              ...               ...
# 18830              Let It Breathe               60            159645
# 18831                     Answers               60            205666
# 18832      Sudden Love (Acoustic)               23            182211
# 18833           Gentle on My Mind               55            352280
# 18834                    Up to Me               60            193533
#
#        acousticness  danceability  energy  instrumentalness  key  liveness  \
# ...

# %%
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import seaborn as sns
#First thing I will do is input all the libraries that I will need for my analysis.

# %%
df = music.loc[0:499]
df
#As a group we have decided to only use 500 rows of data as the original dataset is quite lengthy.
# Out:
#                       song_name  song_popularity  song_duration_ms  \
# 0    Boulevard of Broken Dreams               73            262333
# 1                    In The End               66            216933
# 2             Seven Nation Army               76            231733
# 3                    By The Way               74            216933
# 4             How You Remind Me               56            223826
# ..                          ...              ...               ...
# 495                 China Grove               67            195306
# 496        Foreplay / Long Time               64            467640
# 497              Come Sail Away               59            365000
# 498           Give A Little Bit               72            248173
# 499              Doctor My Eyes               64            199906
#
#      acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0        0.005520         0.496   0.682          0.000029    8    0.0589
# ...

# %%
df.columns
# Out:
# Index(['song_name', 'song_popularity', 'song_duration_ms', 'acousticness',
#        'danceability', 'energy', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'audio_mode', 'speechiness', 'tempo', 'time_signature',
#        'audio_valence'],
#       dtype='object')

# %%
df.shape
# Out:
# (500, 15)

# %%
df.head()
# Out:
#                     song_name  song_popularity  song_duration_ms  \
# 0  Boulevard of Broken Dreams               73            262333
# 1                  In The End               66            216933
# 2           Seven Nation Army               76            231733
# 3                  By The Way               74            216933
# 4           How You Remind Me               56            223826
#
#    acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0      0.005520         0.496   0.682          0.000029    8    0.0589
# 1      0.010300         0.542   0.853          0.000000    3    0.1080
# 2      0.008170         0.737   0.463          0.447000    0    0.2550
# 3      0.026400         0.451   0.970          0.003550    0    0.1020
# 4      0.000954         0.447   0.766          0.000000   10    0.1130
#
#    loudness  audio_mode  speechiness    tempo  time_signature  audio_valence
# ...

# %%
df.nunique(axis=0)
# Out:
# song_name           489
# song_popularity      70
# song_duration_ms    485
# acousticness        437
# danceability        328
# energy              346
# instrumentalness    308
# key                  12
# liveness            334
# loudness            482
# audio_mode            2
# speechiness         342
# tempo               487
# time_signature        4
# audio_valence       362
# dtype: int64

# %%
#Now that I am aware of every variable in my dataset, I will take a closer look at the various values of each variable to better address my research questions.
df.describe().apply(lambda s: s.apply(lambda x: format(x, 'f')))
# Out:
#       song_popularity song_duration_ms acousticness danceability      energy  \
# count      500.000000       500.000000   500.000000   500.000000  500.000000
# mean        63.738000    237185.396000     0.257111     0.574590    0.663005
# std         15.134314     84436.731323     0.270373     0.155420    0.212116
# min          4.000000    120173.000000     0.000007     0.149000    0.040400
# 25%         57.750000    193333.000000     0.022750     0.465000    0.514750
# 50%         67.000000    220613.000000     0.154000     0.579500    0.700000
# 75%         74.000000    261456.000000     0.407250     0.680500    0.831250
# max         98.000000   1233666.000000     0.953000     0.967000    0.988000
#
#       instrumentalness         key    liveness    loudness  audio_mode  \
# count       500.000000  500.000000  500.000000  500.000000  500.000000
# mean          0.041036    5.060000    0.165484   -7.877782    0.652000
# ...

# %%
# As can be seen above, there is some variation in song duration, key, loudness and tempo. 
df_clean = df.copy().drop(['audio_mode'], axis=1)
df_clean

# I will be dropping the audio_mode column as there is not much variation in it therefore it will not affect the dataset too much
# Out:
#                       song_name  song_popularity  song_duration_ms  \
# 0    Boulevard of Broken Dreams               73            262333
# 1                    In The End               66            216933
# 2             Seven Nation Army               76            231733
# 3                    By The Way               74            216933
# 4             How You Remind Me               56            223826
# ..                          ...              ...               ...
# 495                 China Grove               67            195306
# 496        Foreplay / Long Time               64            467640
# 497              Come Sail Away               59            365000
# 498           Give A Little Bit               72            248173
# 499              Doctor My Eyes               64            199906
#
#      acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0        0.005520         0.496   0.682          0.000029    8    0.0589
# ...

# %%
# Now that I have sifted through my dataset, I will be using the variables that I need to create plots/graphs to be able to answer my research questions.

# %% [markdown]
# ## Plotting variables that relate to my research question in correlation with song popularity.
#
# Since one of my research questions was about repeated choruses being more popular than other songs, I have still not been able to figure out a way to sift through finding repeated choruses in a song, but there could possibly be a way for me to do something similar using one of the variables. The variable speechiness means the detection of the presence of spoken words in music. If I can create a plot or image that portrays this correlation, then it might bring me closer to possibly answering my research question.
#
# My next question was about genres of music. Now in this there is no column for genres, but I may be able to answer this question by looking at possibly 2 different columns that have to do with genre: the tempo, and danceability. Different genres of songs have different tempo, for example rock is faster than contemporary so tempo would be a good variable to look at in terms of that. As well as danceability; different genres of songs are more danceable than others, for example Hip-Hop is more danceable than soul music.

# %% [markdown]
# ## Now, I will plot song popularity with speechiness to see if there is any correlation.

# %%
## Now, I will plot song popularity with speechiness to see if there is any correlation.
df_clean.plot(kind='scatter', x='speechiness', y='song_popularity')
# Out:
# <AxesSubplot:xlabel='speechiness', ylabel='song_popularity'>

# %% [markdown]
# ## Analysis of Song popularity and Speechiness scatter plot
# With this scatter plot, I am able to notice that most of the songs do not have that many words. The most “speechy” song is not as popular compared to other “non speechy” songs. In fact the most popular song in the dataset has a speechiness of about 0.25. This also means that the song with a high speechiness value seems more of an outlier in the dataset since it is so far away from all the other songs. This also tells me that less words in a song increase the chance of the song being popular in this dataset.

# %%
df_clean.plot(kind='scatter', x='tempo', y='song_popularity')
# Out:
# <AxesSubplot:xlabel='tempo', ylabel='song_popularity'>

# %% [markdown]
# ## Analysis of Song popularity and Tempo scatter plot
# There is not much correlation between the tempo and popularity of a song. The data is all over the place but mostly concentrated between 90 -140 tempo, meaning medium level tempo of songs have a higher popularity than high level or low level tempo songs. This also means that the higher the tempo of a song does not necessarily mean the song will be more popular.

# %%
df_clean.plot(kind='scatter', x='danceability', y='song_popularity')
# Out:
# <AxesSubplot:xlabel='danceability', ylabel='song_popularity'>

# %% [markdown]
# ## Analysis of Song popularity and Danceability scatter plot
#
# Again, there is not much correlation with danceability and popularity of a song. This data is all
# over the place like that in tempo. There is a cluster of songs in the middle of the plot with a
# danceability of 0.4-0.7 and popularity of approximately 80. Although I do see that some
# danceable songs are very popular as well as less danceable songs are also popular. This
# means the danceability of a song does not have much effect on what makes it popular.

# %% [markdown]
# ## Refined Research questions
#
# ### Are songs with repeated verses or choruses considered more catchy or popular than songs without?
# #### Follow up question: Is there another variable paired with words that can influence the popularity of song?
#
# Looking at the first plot in my EDA, it is evident that the wordiness of a song does have an impact on the popularity. My initial thought was that the more words in a song, the more popular it will be, but actually it is quite the opposite. The fewer words in a song make it more popular. This makes sense in the sense of remembering the song. It is easier to remember a song if it does not have a lot of words. But there are also songs that are not as wordy that are not popular. I want to know if it has to do with just words or is there another variable that when paired with speechiness  influences the popularity of a song.If I am able to figure this out, then the one outlier in my plot might make more sense as to why it si so far off.
#
#
# ## Are there specific genres of music that are more popular than others?
#
# I am still not able to answer this question because both of the features of songs that I thought would relate to the genre do not have a strong correlation with popularity of songs. I think in order to properly tackle this, I will need to go through every song in the dataset to figure out what the genre is, make a new column called genre, then run that against the song_popularity column to be able to see if a certain genre is more popular than other genres. This will be time consuming but it will be very beneficial to answering my question.

# %%
import numpy as np
import pandas as pd
music = pd.read_csv("../data/raw/song_data.csv.zip")
music
# Out:
#                         song_name  song_popularity  song_duration_ms  \
# 0      Boulevard of Broken Dreams               73            262333
# 1                      In The End               66            216933
# 2               Seven Nation Army               76            231733
# 3                      By The Way               74            216933
# 4               How You Remind Me               56            223826
# ...                           ...              ...               ...
# 18830              Let It Breathe               60            159645
# 18831                     Answers               60            205666
# 18832      Sudden Love (Acoustic)               23            182211
# 18833           Gentle on My Mind               55            352280
# 18834                    Up to Me               60            193533
#
#        acousticness  danceability  energy  instrumentalness  key  liveness  \
# ...

# %%
songs = music.loc[0:499]
songs
# Out:
#                       song_name  song_popularity  song_duration_ms  \
# 0    Boulevard of Broken Dreams               73            262333
# 1                    In The End               66            216933
# 2             Seven Nation Army               76            231733
# 3                    By The Way               74            216933
# 4             How You Remind Me               56            223826
# ..                          ...              ...               ...
# 495                 China Grove               67            195306
# 496        Foreplay / Long Time               64            467640
# 497              Come Sail Away               59            365000
# 498           Give A Little Bit               72            248173
# 499              Doctor My Eyes               64            199906
#
#      acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0        0.005520         0.496   0.682          0.000029    8    0.0589
# ...

# %%
songs_cleaned = songs.drop(['audio_mode', 'time_signature'], axis=1)
songs_cleaned
#Cleaning the data. Here I am cleaning the data by removing 2 columns that are not significant in my research or are just repetitive.
# Out:
#                       song_name  song_popularity  song_duration_ms  \
# 0    Boulevard of Broken Dreams               73            262333
# 1                    In The End               66            216933
# 2             Seven Nation Army               76            231733
# 3                    By The Way               74            216933
# 4             How You Remind Me               56            223826
# ..                          ...              ...               ...
# 495                 China Grove               67            195306
# 496        Foreplay / Long Time               64            467640
# 497              Come Sail Away               59            365000
# 498           Give A Little Bit               72            248173
# 499              Doctor My Eyes               64            199906
#
#      acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0        0.005520         0.496   0.682          0.000029    8    0.0589
# ...

# %%
songs_cleaned['danceable_valence'] = songs_cleaned['danceability'] + songs_cleaned['audio_valence']
# These 2 variables have very similar values so I combined them
songs_cleaned
# Out:
#                       song_name  song_popularity  song_duration_ms  \
# 0    Boulevard of Broken Dreams               73            262333
# 1                    In The End               66            216933
# 2             Seven Nation Army               76            231733
# 3                    By The Way               74            216933
# 4             How You Remind Me               56            223826
# ..                          ...              ...               ...
# 495                 China Grove               67            195306
# 496        Foreplay / Long Time               64            467640
# 497              Come Sail Away               59            365000
# 498           Give A Little Bit               72            248173
# 499              Doctor My Eyes               64            199906
#
#      acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0        0.005520         0.496   0.682          0.000029    8    0.0589
# ...

# %% [markdown]
# # Wrangling data

# %% [markdown]
# #### Since one of my research questions has to do with genres of a song, but I cannot find all the genres because it is not only time consuming, but there are multiple songs with that one title and I will not be able to figure out all of it so I am just going to find the top 30 popular songs and 30 least popular songs and their genres and attempt to answer my question that way.

# %%
most_popular = songs_cleaned.sort_values("song_popularity", ascending=False).head(30)
most_popular #these songs are the top popular songs in this dataset
# Out:
#                                              song_name  song_popularity  \
# 61      Taki Taki (with Selena Gomez, Ozuna & Cardi B)               98
# 86                                           I Like It               95
# 85                                                BEBE               95
# 64                    Beautiful (feat. Camila Cabello)               94
# 60                                   MIA (feat. Drake)               94
# 70                                  Wake Up in the Sky               92
# 101        1, 2, 3 (feat. Jason Derulo & De La Ghetto)               88
# 65                                              Celoso               87
# 67                                        Real Friends               85
# 131                                          All of Me               85
# 212                                     Hips Don't Lie               84
# 114                    Finesse (Remix) [feat. Cardi B]               84
# ...

# %%
new_most_popular = most_popular.drop(labels=[353,126,155,173,364], axis=0)
new_most_popular
#when individually finding the genre of each song I saw that my data had duplicate rows but with different numbers so I just removed the 2 duplicate rows so I will not get false data.Also, I will remove the song "Bleeding love" simply because there are many songs with that title and I cannot differentiate them.
# Out:
#                                              song_name  song_popularity  \
# 61      Taki Taki (with Selena Gomez, Ozuna & Cardi B)               98
# 86                                           I Like It               95
# 85                                                BEBE               95
# 64                    Beautiful (feat. Camila Cabello)               94
# 60                                   MIA (feat. Drake)               94
# 70                                  Wake Up in the Sky               92
# 101        1, 2, 3 (feat. Jason Derulo & De La Ghetto)               88
# 65                                              Celoso               87
# 67                                        Real Friends               85
# 131                                          All of Me               85
# 212                                     Hips Don't Lie               84
# 114                    Finesse (Remix) [feat. Cardi B]               84
# ...

# %%
# After all my sorting, I now have the genres of the top 25 songs in my dataset and I will addthem into my data under a new column titled "genre".
Genre = ['Reggae', 'Hip Hop', 'Pop', 'Pop', 'Hip Hop', 'Pop', 'Hip Hop', 'Reggae', 'Reggae', 'R&B', 'Pop', 'Pop', 'Pop', 'Rock', 'Pop', 'Rock', 'Pop', 'Rock', 'R&B', 'Rock',  'Rock', 'Metal','Rock', 'Rock', 'R&B'] 
new_most_popular['Genre'] = Genre
new_most_popular
# Out:
#                                              song_name  song_popularity  \
# 61      Taki Taki (with Selena Gomez, Ozuna & Cardi B)               98
# 86                                           I Like It               95
# 85                                                BEBE               95
# 64                    Beautiful (feat. Camila Cabello)               94
# 60                                   MIA (feat. Drake)               94
# 70                                  Wake Up in the Sky               92
# 101        1, 2, 3 (feat. Jason Derulo & De La Ghetto)               88
# 65                                              Celoso               87
# 67                                        Real Friends               85
# 131                                          All of Me               85
# 212                                     Hips Don't Lie               84
# 114                    Finesse (Remix) [feat. Cardi B]               84
# ...

# %%
new_most_popular_2 = new_most_popular.reindex(columns=['song_name', 'Genre',
'song_popularity', 'song_duration_ms', 'acousticness','danceability', 'energy', 'key', 'liveness',
'loudness' , 'spechiness' , 'tempo' 'audio_valence' , 'danceable_valence'])
new_most_popular_2
# Out:
#                                              song_name    Genre  \
# 61      Taki Taki (with Selena Gomez, Ozuna & Cardi B)   Reggae
# 86                                           I Like It  Hip Hop
# 85                                                BEBE      Pop
# 64                    Beautiful (feat. Camila Cabello)      Pop
# 60                                   MIA (feat. Drake)  Hip Hop
# 70                                  Wake Up in the Sky      Pop
# 101        1, 2, 3 (feat. Jason Derulo & De La Ghetto)  Hip Hop
# 65                                              Celoso   Reggae
# 67                                        Real Friends   Reggae
# 131                                          All of Me      R&B
# 212                                     Hips Don't Lie      Pop
# 114                    Finesse (Remix) [feat. Cardi B]      Pop
# 128                                    Pumped Up Kicks      Pop
# 414                      Hotel California - Remastered     Rock
# ...

# %%
#Now I am going to take account of the 30 least popular songs in the dataset in order for me to have a nice correlation between the top songs and bottom songs.

least_popular = songs_cleaned.sort_values("song_popularity", ascending =True).head(30)
least_popular #these songs are the least popular songs in this dataset
# Out:
#                                              song_name  song_popularity  \
# 225                                            Querida                4
# 229                    I Know You Want Me (Calle Ocho)                7
# 234                                       Besame Mucho                7
# 237                                          Chan Chan                7
# 338              Psychotic Reaction - Rarities Version                8
# 121                                    Beautiful Girls               10
# 36                                       The Pretender               11
# 30                                         All My Life               11
# 210                                         El Matador               11
# 282                                  Hit the Road Jack               13
# 22                                        No One Knows               13
# 363                           Wildflowers - Remastered               13
# ...

# %%
#Same thing I did for the most popular songs is what I will do for the least popular songs now.
Genre = ['Latin Pop', 'Son cubano', 'Bolero', 'Hip Hop', 'Rock', 'R&B', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Salsa', 'Rock', 'Pop', 'R&B', 'Rock', 'Pop' , 'R&B', 'Rock', 'Rock', 'Country', 'R&B', 'Pop', 'Rock', 'Rock', 'Hip Hop',] 
least_popular['Genre'] = Genre
least_popular
# Out:
#                                              song_name  song_popularity  \
# 225                                            Querida                4
# 229                    I Know You Want Me (Calle Ocho)                7
# 234                                       Besame Mucho                7
# 237                                          Chan Chan                7
# 338              Psychotic Reaction - Rarities Version                8
# 121                                    Beautiful Girls               10
# 36                                       The Pretender               11
# 30                                         All My Life               11
# 210                                         El Matador               11
# 282                                  Hit the Road Jack               13
# 22                                        No One Knows               13
# 363                           Wildflowers - Remastered               13
# ...

# %%
import matplotlib.pylab as plt
import seaborn as sns

new_least_popular = least_popular.reindex(columns=['song_name', 'Genre',
'song_popularity', 'song_duration_ms', 'acousticness','danceability', 'energy', 'key', 'liveness',
'loudness' , 'spechiness' , 'tempo' 'audio_valence' , 'danceable_valence'])
new_least_popular
# Out:
#                                              song_name       Genre  \
# 225                                            Querida   Latin Pop
# 229                    I Know You Want Me (Calle Ocho)  Son cubano
# 234                                       Besame Mucho      Bolero
# 237                                          Chan Chan     Hip Hop
# 338              Psychotic Reaction - Rarities Version        Rock
# 121                                    Beautiful Girls         R&B
# 36                                       The Pretender        Rock
# 30                                         All My Life        Rock
# 210                                         El Matador        Rock
# 282                                  Hit the Road Jack        Rock
# 22                                        No One Knows        Rock
# 363                           Wildflowers - Remastered        Rock
# 331                                          I'm A Man        Rock
# ...

# %%
conjoined_df = pd.concat([new_most_popular_2, new_least_popular], ignore_index=True)
conjoined_df
# Out:
#                                             song_name       Genre  \
# 0      Taki Taki (with Selena Gomez, Ozuna & Cardi B)      Reggae
# 1                                           I Like It     Hip Hop
# 2                                                BEBE         Pop
# 3                    Beautiful (feat. Camila Cabello)         Pop
# 4                                   MIA (feat. Drake)     Hip Hop
# 5                                  Wake Up in the Sky         Pop
# 6         1, 2, 3 (feat. Jason Derulo & De La Ghetto)     Hip Hop
# 7                                              Celoso      Reggae
# 8                                        Real Friends      Reggae
# 9                                           All of Me         R&B
# 10                                     Hips Don't Lie         Pop
# 11                    Finesse (Remix) [feat. Cardi B]         Pop
# 12                                    Pumped Up Kicks         Pop
# ...

# %%
#This builds the method chain of the above codes for the top 30 songs
Genre = ['Reggae', 'Hip Hop', 'Pop', 'Pop', 'Hip Hop', 'Pop', 'Hip Hop', 'Reggae', 'Reggae', 'R&B', 'Pop', 'Pop', 'Pop', 'Rock', 'Pop', 'Rock', 'Pop', 'Rock', 'R&B', 'Rock',  'Rock', 'Metal','Rock', 'Rock', 'R&B'] 

new_most_popular = (songs_cleaned
                   .sort_values("song_popularity", ascending=False)
                   .head(30)
                   .drop(labels=[353,126,155,173,364], axis=0)
                   .assign(Genre=Genre))
new_most_popular
# Out:
#                                              song_name  song_popularity  \
# 61      Taki Taki (with Selena Gomez, Ozuna & Cardi B)               98
# 86                                           I Like It               95
# 85                                                BEBE               95
# 64                    Beautiful (feat. Camila Cabello)               94
# 60                                   MIA (feat. Drake)               94
# 70                                  Wake Up in the Sky               92
# 101        1, 2, 3 (feat. Jason Derulo & De La Ghetto)               88
# 65                                              Celoso               87
# 67                                        Real Friends               85
# 131                                          All of Me               85
# 212                                     Hips Don't Lie               84
# 114                    Finesse (Remix) [feat. Cardi B]               84
# ...

# %%
#This builds the method chain of the above codes for the least popular songs
Genre = ['Latin Pop', 'Son cubano', 'Bolero', 'Hip Hop', 'Rock', 'R&B', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Salsa', 'Rock', 'Pop', 'R&B', 'Rock', 'Pop' , 'R&B', 'Rock', 'Rock', 'Country', 'R&B', 'Pop', 'Rock', 'Rock', 'Hip Hop',]

new_least_popular = (songs_cleaned
                   .sort_values("song_popularity", ascending=True)
                   .head(30)
                   .assign(Genre=Genre))
new_least_popular
# Out:
#                                              song_name  song_popularity  \
# 225                                            Querida                4
# 229                    I Know You Want Me (Calle Ocho)                7
# 234                                       Besame Mucho                7
# 237                                          Chan Chan                7
# 338              Psychotic Reaction - Rarities Version                8
# 121                                    Beautiful Girls               10
# 36                                       The Pretender               11
# 30                                         All My Life               11
# 210                                         El Matador               11
# 282                                  Hit the Road Jack               13
# 22                                        No One Knows               13
# 363                           Wildflowers - Remastered               13
# ...

# %%
#This code wraps my data into a function for both the most and least popular. 
def process_songs(songs_cleaned):
    most_popular_genre = ['Reggae', 'Hip Hop', 'Pop', 'Pop', 'Hip Hop', 'Pop', 'Hip Hop', 'Reggae', 'Reggae', 'R&B', 'Pop', 'Pop', 'Pop', 'Rock', 'Pop', 'Rock', 'Pop', 'Rock', 'R&B', 'Rock', 'Rock', 'Metal','Rock', 'Rock', 'R&B']
    least_popular_genre = ['Latin Pop', 'Son cubano', 'Bolero', 'Hip Hop', 'Rock', 'R&B', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Salsa', 'Rock', 'Pop', 'R&B', 'Rock', 'Pop' , 'R&B', 'Rock', 'Rock', 'Country', 'R&B', 'Pop', 'Rock', 'Rock', 'Hip Hop']
    
    new_most_popular = (songs_cleaned
                       .sort_values("song_popularity", ascending=False)
                       .head(30)
                       .drop(labels=[353,126,155,173,364], axis=0)
                       .assign(Genre=most_popular_genre)
                      )
    
    new_least_popular = (songs_cleaned
                       .sort_values("song_popularity", ascending=True)
                       .head(30)
                       .assign(Genre=least_popular_genre)
                      )
    
    conjoined_df = pd.concat([new_most_popular[new_least_popular.columns], new_least_popular], ignore_index=True)
    
    return conjoined_df
processed_songs = process_songs(songs_cleaned)

# %%
grouped = conjoined_df.groupby('Genre')['song_popularity'].mean()
plt.barh(grouped.index, grouped.values)

plt.xlabel('Mean Song Popularity')
plt.ylabel('Genre')
plt.title('Average Song Popularity according to Genre')

plt.show()

# %% [markdown]
# ### Bar Graph Explanation
# ##### This bar graph portrays the frequency of the genres of the top 25 songs in the dataset and the bottom 30 songs. From the looks of it, in accordance to the mean song popularity, the most popular genres are Raggae, Metal, Pop and Hip-Hop. This answers my research question that yes, some song genres are more popular than others. Although the amount of sample data is small (55) in comparison to the whole dataset, it does still give a sense of the types of music people consider popular, and according to this dataset, it is Raggae, Metal, Pop and Hip-Hop.

# %%
# Subset the data for the four genres of interest
modified_df = conjoined_df[conjoined_df['Genre'].isin(['Reggae', 'Metal', 'Pop', 'Hip Hop'])]

sns.stripplot(x='Genre', y='song_popularity', data=modified_df)

plt.xlabel('Genre')
plt.ylabel('Song Popularity')
plt.title('Song Popularity by Genre')

plt.show()

# %% [markdown]
# ## Strip Plot Explanation
#
# #### The image above depicts a Strip plot of the 4 most popular songs in the dataset according to genre. This strip plot demostrates the correlation of the least and most popular songs in relation to genre

# %%
modified_df = conjoined_df[conjoined_df['Genre'].isin(['Reggae', 'Metal', 'Pop', 'Hip Hop'])]

sns.violinplot(x='Genre', y='song_popularity', data=modified_df)

plt.xlabel('Genre')
plt.ylabel('Song Popularity')
plt.title('Song Popularity by Genre')

plt.show()

# %% [markdown]
# ### Violin plot of Top Popular Genres
#
# ##### The graph above showcases a violin plot of the top 4 genres. This portrays a better depiction of the range of popularity for each genre. The Reggae genre does not have much range meaning most Reggae songs are popular.In Hip-Hop and Pop, we see that it has quite a wide range in the sense of popularity meaning there are both popular and non-popular songs. The metal genre however is quite different from the rest as we see it is only the popular songs that are metal and no non-popular songs because there was only 1 metal song. This does not show accurate data for the metal genre

# %%
conjoined_df.to_csv('project-group-group48.csv')
